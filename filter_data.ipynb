# %%
import os
import json
import torch

import numpy as np
from tqdm import tqdm
from typing import List, Union
from transformers import AutoTokenizer, AutoModelForSequenceClassification

class CodeScorer:
    def __init__(self, model_name, device="cuda" if torch.cuda.is_available() else "cpu"):
        self.model = AutoModelForSequenceClassification.from_pretrained(
            model_name, num_labels=1).to(device)
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.tokenizer.pad_token = self.tokenizer.eos_token
        self.device = device

    def score(self, codes: Union[str, List[str]]) -> List[float]:
        if isinstance(codes, str):
            codes = [codes]
        if len(codes) == 0:
            return []
        self.model.eval()
        with torch.no_grad():
            inputs = self.tokenizer(
                codes,
                truncation=True,
                padding=True,
                max_length=1000,
                return_tensors="pt"
            ).to(self.device)
            outputs = self.model(**inputs)
            logits = outputs.logits
            preds = [float(x) for x in logits.squeeze(-1).tolist()]
            return preds

scorer = CodeScorer("weights")

# %%
lst = set()
with open("datasets/pfall.jsonl", "r") as f:
    for row in f:
        data = json.loads(row)
        string = data["prompt"] + data["completion"]
        trimmed_string = "\n".join(string.split("\n")[2:])
        if len(trimmed_string) < 10 or len(trimmed_string) > 1000:
            continue
        lst.add(string)

lst = list(lst)
print(f"num entrys: {len(lst)}")
# Out:
# num entrys: 1406441

# %%
import pandas as pd

limit = -1

dct = {}
scores = []
for i, x in tqdm(enumerate(lst[:limit]), total=len(lst[:limit])):
    trimmed_x = "\n".join(x.split("\n")[2:])
    score = scorer.score(x)
    scores.append(score)
    dct[x] = score

with open('data.json', 'w') as fp:
    json.dump(dct, fp)
    
scores = np.array(scores)
df_describe = pd.DataFrame(scores)
df_describe.describe()
# Out:
#   0%|          | 929/1406440 [01:19<33:16:18, 11.73it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 9
#       7 for i, x in tqdm(enumerate(lst[:limit]), total=len(lst[:limit])):
#       8     trimmed_x = "\n".join(x.split("\n")[2:])
# ----> 9     score = scorer.score(x)
#      10     scores.append(score)
#      11     dct[x] = score
#
# Cell In[3], line 32, in CodeScorer.score(self, codes)
#      24 with torch.no_grad():
#      25     inputs = self.tokenizer(
#      26         codes,
#      27         truncation=True,
#    (...)
#      30         return_tensors="pt"
#      31     ).to(self.device)
# ---> 32     outputs = self.model(**inputs)
#      33     logits = outputs.logits
#      34     preds = [float(x) for x in logits.squeeze(-1).tolist()]
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:1562, in BertForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1554 r"""
#    1555 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1556     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1557     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1558     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1559 """
#    1560 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1562 outputs = self.bert(
#    1563     input_ids,
#    1564     attention_mask=attention_mask,
#    1565     token_type_ids=token_type_ids,
#    1566     position_ids=position_ids,
#    1567     head_mask=head_mask,
#    1568     inputs_embeds=inputs_embeds,
#    1569     output_attentions=output_attentions,
#    1570     output_hidden_states=output_hidden_states,
#    1571     return_dict=return_dict,
#    1572 )
#    1574 pooled_output = outputs[1]
#    1576 pooled_output = self.dropout(pooled_output)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:1020, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1011 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#    1013 embedding_output = self.embeddings(
#    1014     input_ids=input_ids,
#    1015     position_ids=position_ids,
#    (...)
#    1018     past_key_values_length=past_key_values_length,
#    1019 )
# -> 1020 encoder_outputs = self.encoder(
#    1021     embedding_output,
#    1022     attention_mask=extended_attention_mask,
#    1023     head_mask=head_mask,
#    1024     encoder_hidden_states=encoder_hidden_states,
#    1025     encoder_attention_mask=encoder_extended_attention_mask,
#    1026     past_key_values=past_key_values,
#    1027     use_cache=use_cache,
#    1028     output_attentions=output_attentions,
#    1029     output_hidden_states=output_hidden_states,
#    1030     return_dict=return_dict,
#    1031 )
#    1032 sequence_output = encoder_outputs[0]
#    1033 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:610, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     601     layer_outputs = torch.utils.checkpoint.checkpoint(
#     602         create_custom_forward(layer_module),
#     603         hidden_states,
#    (...)
#     607         encoder_attention_mask,
#     608     )
#     609 else:
# --> 610     layer_outputs = layer_module(
#     611         hidden_states,
#     612         attention_mask,
#     613         layer_head_mask,
#     614         encoder_hidden_states,
#     615         encoder_attention_mask,
#     616         past_key_value,
#     617         output_attentions,
#     618     )
#     620 hidden_states = layer_outputs[0]
#     621 if use_cache:
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:537, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     534     cross_attn_present_key_value = cross_attention_outputs[-1]
#     535     present_key_value = present_key_value + cross_attn_present_key_value
# --> 537 layer_output = apply_chunking_to_forward(
#     538     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     539 )
#     540 outputs = (layer_output,) + outputs
#     542 # if decoder, return the attn key/values as the last output
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/transformers/pytorch_utils.py:236, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     233     # concatenate output at same dimension
#     234     return torch.cat(output_chunks, dim=chunk_dim)
# --> 236 return forward_fn(*input_tensors)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:549, in BertLayer.feed_forward_chunk(self, attention_output)
#     548 def feed_forward_chunk(self, attention_output):
# --> 549     intermediate_output = self.intermediate(attention_output)
#     550     layer_output = self.output(intermediate_output, attention_output)
#     551     return layer_output
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:450, in BertIntermediate.forward(self, hidden_states)
#     448 def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
#     449     hidden_states = self.dense(hidden_states)
# --> 450     hidden_states = self.intermediate_act_fn(hidden_states)
#     451     return hidden_states
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/transformers/activations.py:78, in GELUActivation.forward(self, input)
#      77 def forward(self, input: Tensor) -> Tensor:
# ---> 78     return self.act(input)
#
# KeyboardInterrupt:

# %%
low_quality_scripts_dct = {}
high_quality_scripts_dct = {}

for script, score in tqdm(zip(lst[:limit], scores[:limit])):
    if score < 0.4:
        low_quality_scripts_dct[script] = score
    if score > 0.75:
        high_quality_scripts_dct[script] = score
# Out:
# 1000it [00:00, 476842.20it/s]

# %%
for low_quality_script, score in low_quality_scripts_dct.items():
    print("=" * 40)
    print(f"Script:\n{low_quality_script}")
    print(f"Score: {score}")
# Out:
# ========================================
# Script:
# -- Path: WAI_script.server.lua
# -- ROBMeta: Workspace/Whack-an-iAllure
# -- manages the Whack-an-iAllure room
#
# Score: [0.38993114]
# ========================================
# Script:
# -- Path: 219773.lua
# -- ROBMeta: ReplicatedStorage/LOD/Close
# local data={
# {"tree_med_1",CFrame.new(452.22348022461,45.588024139404,3766.6313476563,0.38966590166092,0.033821139484644,-0.92033511400223,-0.015536633320153,0.99942463636398,0.03014943562448,0.92082518339157,0.0025507020764053,0.38996714353561)},
# }
# return data
#
# Score: [0.37049186]
# ========================================
# Script:
# -- Path: Constants.lua
# -- ROBMeta: ReplicatedStorage/Modules
# -- Maximum lobby size
# Constants.MaxLobbySize = 10
#
#
#
# Score: [0.39252564]
# ========================================
# Script:
# -- Path: mouseLocal.client.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts
# --			print("WTF NO LOCAL PLAYER ROOT!")
# 			return
# 		end
#
#
# 		local t, pos = getMousePoint(mouse.X,mouse.Y)
#
# 		if t then
# 			local curr
#
# 			if t.Parent:FindFirstChild("barracks") then
# Score: [0.39013433]
# ========================================
# Script:
# -- Path: ResolutionFix.client.lua
# -- ROBMeta: ServerStorage/GUI/Menu/Pages/LoadoutPage/SideBar/AmmoList
# --Variables
# local currentCamera = workspace.CurrentCamera
#
# Score: [0.33851719]
# ========================================
# Script:
# -- Path: SpeedEffect.server.lua
# -- ROBMeta: Workspace/Epic Soda Machine by KnightlyKnave/Gatorade
# print("run latte")
#
#
# Score: [0.32739699]
# ========================================
# Script:
# -- Path: DieselSounds2.lua
# -- ROBMeta: ServerStorage/Class20(F)/Class20/DCCFunctions
# -- MADE BY NWSPACEK
#
# Score: [0.38958833]
# ========================================
# Script:
# -- Path: MonsterHandler.server.lua
# -- ROBMeta: ReplicatedStorage/Prefab/FieldMonster/Mummy/Head/HealthGui
# --Moudle
# local Tween = require(game.ReplicatedStorage.Module.ModuleTween)
# local Function = require(game.ReplicatedStorage.Module.Function)
#
#
# Score: [0.36591351]
# ========================================
# Script:
# -- Path: Setting.lua
# -- ROBMeta: ServerStorage/BurstRifle
# --		How "ShotgunEnabled" work [Example]:
#
# Score: [0.38860303]
# ========================================
# Script:
# -- Path: GlobalLeaderboards.server.lua
# -- ROBMeta: ServerScriptService
# --XandertjeKnal
#
# Score: [0.26182944]
# ========================================
# Script:
# -- Path: Script.server.lua
# -- ROBMeta: ReplicatedFirst/BanHammer-Infinite4/Hit
# --debounce = true
# if script.Parent.Activvated.Value == true then
# script.Parent.BanDelay.Value = true
# script.Parent.Activvated.Value = false
# script.Parent.DB.Value = true
# Score: [0.33585858]
# ========================================
# Script:
# -- Path: Script.server.lua
# -- ROBMeta: Workspace/Levels/Clothing/Jeans
# door = script.Parent --this is the door
# Decal = script.Parent.Decal
#
# function onChatted(msg, recipient, speaker)
#
# Score: [0.30093437]
# ========================================
# Script:
# -- Path: Leaderboard.server.lua
# -- ROBMeta: ServerScriptService/Systems
# --Services
# local ReplicatedStorage = game:GetService("ReplicatedStorage")
# local ServerStorage = game:GetService("ServerStorage")
# local Players = game:GetService("Players")
#
# Score: [0.3852967]
# ========================================
# Script:
# -- Path: InAir.server.lua
# -- ROBMeta: ServerStorage/Tools/Football/ServerScripts
# --wait(3)
# --Connection:disconnect()
# --projectile.Parent = nil
#
# Score: [0.31870171]
# ========================================
# Script:
# -- Path: Script.server.lua
# -- ROBMeta: Workspace/Vito/Vehicle/DriveSeat
# local minrank = 0 --// minimum rank krşm (buraya yazdıgın rank numararsının üstündeki ranklar binebilir bu numara ve altı binemez)
# local accepted = 14517413 --// grup id krşm
#
# Score: [0.3963221]
# ========================================
# Script:
# -- Path: BIGHAMMER.lua
# -- ROBMeta: ServerStorage/ClassData/Birthstroyer/Client/Skills
# --local weaponTrail = char:WaitForChild("Babber"):WaitForChild("EFFECT"):WaitForChild("SparkleTrail")
#
# local verifyCDFunc = remotesFolder:WaitForChild("VerifyCD")
#
# Score: [0.32835647]
# ========================================
# Script:
# -- Path: Config.lua
# -- ROBMeta: ServerStorage/Vehicles/Renault/R312
# --[[
# 		___      _______                _
# 	   / _ |____/ ___/ /  ___ ____ ___ (_)__
# 	  / __ /___/ /__/ _ \/ _ `(_-<(_-</ (_-<
# 	 /_/ |_|   \___/_//_/\_,_/___/___/_/___/
#  						SecondLogic @ Inspare
# ]]
#
# local Tune = {}
#
# Score: [0.39445293]
# ========================================
# Script:
# -- Path: Report.client.lua
# -- ROBMeta: ServerStorage/PackageStorageDontDelete/_GRP_SG/ScreenGui/PlayerInfo/Frame/BlurbsFrame/Report
# --do anims on stream, *** set up stream curse bot before then.
# local ScriptFinder = require(game.ReplicatedStorage.ScriptFinder)
#
#
# local button = script.Parent
# Score: [0.39499807]
# ========================================
# Script:
# -- Path: ColorPicker.client.lua
# -- ROBMeta: ServerStorage/GUIs/MainscreenTests/Background/Main/ShopContainer/Picker
# --	print("Diff: "..diff);
#
# Score: [0.2975677]
# ========================================
# Script:
# -- Path: fins.lua
# -- ROBMeta: Workspace/SongMaps
# --The artist of your map.
# rtv.AudioArtist = "bonespook/Emersyn"
# Score: [0.38151729]
# ========================================
# Script:
# -- Path: GunConfigurations.lua
# -- ROBMeta: ServerStorage/NPCStorage/Vehicles/Noob Scout Helicopter/ScoutHelicopterAI
# -- Shooting --
# Configurations.Firerate = 0.8
# Score: [0.37320113]
# ========================================
# Script:
# -- Path: Script.server.lua
# -- ROBMeta: ServerStorage/Model/Mercedes Benz Econic ALP/Misc/Ladder/Base/Model/Seat/LadderUI/Scripts
# -- Lowerarm --
#
# Score: [0.36026406]
# ========================================
# Script:
# -- Path: ItemData.lua
# -- ROBMeta: ReplicatedStorage/Storages/Pets/Tiers/Epic/Presets/RubyZombie
# --		JumpPower = 5,
# 	},
# 	IsEgg = false,
# 	Float = false,
# 	Tier = 'Epic',
# }
#
# Score: [0.35445067]
# ========================================
# Script:
# -- Path: PearlsOfAtlantis03.server.lua
# -- ROBMeta: ServerScriptService/Quests/PearlsOfAtlantis
# -- START -- Kokku -- MGomes
#
# Score: [0.3862851]
# ========================================
# Script:
# -- Path: Script.server.lua
# -- ROBMeta: ReplicatedStorage/Cosmetics/YingYangAura
# --// Character Parts
# local character = script.Parent.Parent.Parent
# local torso = character:WaitForChild("Torso", 5)
#
# Score: [0.37549329]
# ========================================
# Script:
# -- Path: Fire God Wrath.client.lua
# -- ROBMeta: ServerStorage/Magics/Fire God
# --	resize(circle, 20, .5)
# game.ReplicatedStorage.magicsFE["extras"]:InvokeServer("resizecircle",circle, 20, .5)
#
#
#
# Score: [0.29833597]
# ========================================
# Script:
# -- Path: Pumpkin Trap.client.lua
# -- ROBMeta: ServerStorage/Magics/Halloween
# --	resize(circle, 50, 0.15)
# 	game.ReplicatedStorage.magicsFE["extras"]:InvokeServer("resizecircle",circle, 50, 0.15)
#
# Score: [0.31539896]
# ========================================
# Script:
# -- Path: Script.server.lua
# -- ROBMeta: ReplicatedStorage/Items/piece of grass
# -- Mackerel --
# -- Whack Animation, time 0.5 seconds
# -- Whack Sound,  0.4 seconds
#
# Score: [0.34866896]
# ========================================
# Script:
# -- Path: Developer.lua
# -- ROBMeta: ServerScriptService/Features/Services/ProfileService/Icons
# --------------------------------------------------------
# return Icon
#
# Score: [0.34043863]
# ========================================
# Script:
# -- Path: Vengeful Dragon Rush.lua
# -- ROBMeta: ServerStorage/PACKAGE/Moves
# -------|
#
# return VengefulDragonRush;
#
# Score: [0.38520488]
# ========================================
# Script:
# -- Path: Client.client.lua
# -- ROBMeta: ServerStorage/PaidTools/RadioTool
# --connect
# Tool.Equipped:connect(onEquipped)
# Tool.Unequipped:connect(onUnequipped)
# Remote.OnClientEvent:connect(onRemote)
#
# Score: [0.38715193]
# ========================================
# Script:
# -- Path: Setting.lua
# -- ROBMeta: ServerStorage/ContributorWeapons/Prime's Revolver
# --		How "ShotgunEnabled" work [Example]:
#
# Score: [0.39232647]
# ========================================
# Script:
# -- Path: Inventory.server.lua
# -- ROBMeta: ServerScriptService/Scripts/Game
# --------|     Setting     |--------
#
# Score: [0.29686889]
# ========================================
# Script:
# -- Path: GravityCoilScript.server.lua
# -- ROBMeta: ServerStorage/Gears/GravityCoil
# --// Instances //--
# local Tool = script.Parent
# local Mutators = repStor.Mutators
# local body
#
# Score: [0.33052695]
# ========================================
# Script:
# -- Path: LocalScript.client.lua
# -- ROBMeta: ReplicatedStorage/Assets/TSPurchase/Frame/Purchase
# -->
#
# local gui = script.Parent.Parent.Parent
#
# local ShopFrameTween = script.Parent.Parent
#
# local DestroyRemote = game.ReplicatedStorage.RemoteEvents.TSGUI
# DestroyRemote:FireServer()
#
# end
# 	end
# end)
#
#
#
#
# Score: [0.36650431]
# ========================================
# Script:
# -- Path: Client.lua
# -- ROBMeta: ReplicatedStorage/Classes/MPMinigames/Bowling
# -- local TickAPI = require(game.ReplicatedStorage.API.TickAPI)
#
# Score: [0.34944975]
# ========================================
# Script:
# -- Path: Script.server.lua
# -- ROBMeta: Workspace/ImportantBoards/BlocksMined/SurfaceGui
# -- [ END SETTINGS ] --
#
#
#
#
# Score: [0.33340383]
# ========================================
# Script:
# -- Path: Hill Billboard.client.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts/Scripts/GUIs
# --------|    Variables    |--------
#
# Score: [0.29354864]
# ========================================
# Script:
# -- Path: Pickup.server.lua
# -- ROBMeta: ServerStorage/Cars/Ural/DriveSeat
#
# seat = script.Parent
#
# Score: [0.35209215]
# ========================================
# Script:
# -- Path: init.client.lua
# -- ROBMeta: Lighting/ReallyOldSkillFrames/Shadow God Slayer/Stuff/ScrollingFrame/Grand Shadow Ball/Learn/Grand Shadow Ball/LocalScript
# -----------------------------------------------ButtonUpfunction
# function onButtonUp(mouse)
# hold=false
# end
#
#
# function onSelected(mouse)
# mouse.Button1Down:connect(function()onButtonDown(mouse)end)
# mouse.Button1Up:connect(function()onButtonUp(mouse)end)
# end
# script.Parent.Selected:connect(onSelected)
# Score: [0.38959301]
# ========================================
# Script:
# -- Path: Hotbar.lua
# -- ROBMeta: StarterGui/UI/Client/UIHandler
# local m = {}
#
# Score: [0.36525062]
# ========================================
# Script:
# -- Path: RemotesClientSingleton.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts/ClientModules
# -- Client RemoteEvent Manager/Dispatcher
#
# Score: [0.38882589]
# ========================================
# Script:
# -- Path: SpikeBallCombat.lua
# -- ROBMeta: ServerScriptService/Modules/CombatModules/WeaponModules
# -- REMOTES
# local EffectRemote = Replicated.EffectRemote
#
# Score: [0.39749289]
# ========================================
# Script:
# -- Path: PentacleEarrings.lua
# -- ROBMeta: ReplicatedStorage/Shared/Data/Accessories
# -- FOLDERS --
# local Hats = ReplicatedStorage:WaitForChild("Accessories"):WaitForChild("Hat")
#
# Score: [0.38636038]
# ========================================
# Script:
# -- Path: Teleport pad script.server.lua
# -- ROBMeta: ReplicatedStorage/Backrooms/Level3/Teleports/Tele1
# ------------------------------------
# modelname="Tele2"
# Score: [0.33339986]
# ========================================
# Script:
# -- Path: Push.lua
# -- ROBMeta: ServerScriptService/GameScripts/Force - Server
# --//      Made by       \\--
# --\\    Skywalker_SW    //--
#
# Score: [0.3491413]
# ========================================
# Script:
# -- Path: Script.server.lua
# -- ROBMeta: Workspace/Morphs/UpgradesAndSkins/Insanity!Fell/Insanity Sans/Head
# --1 = white
# --208 = Light stone grey
# --194 = Medium stone grey
# --199 = Dark stone grey
# --26 = Black
# --21 = Bright red
# --24 = Bright yellow
# --226 = Cool yellow
# --23 = Bright blue
# --107 = Bright bluish green
# --102 = Medium blue
# --11 = Pastel blue
# --45 = Light blue
# --135 = Sand blue
# --106 = Bright orange
# --105 = Br. yellowish orange
# --141 = Earth green
# --28 = Dark green
# --37 = Bright green
# --119 = Br. yellowish green
# --29 = Medium green
# --151 = Sand green
# --38 = Dark orange
# --192 = Reddish brown
# --104 = Bright violet
# --9 = Light reddish violet
# --101 = Medium red
# --5 = Brick Yellow
# --153 = Sand red
# --217 = Brown
# --18 = Nougat
# --125 = Light orange
#
#
# Score: [0.39297584]
# ========================================
# Script:
# -- Path: chatTags.server.lua
# -- ROBMeta: ServerScriptService/PlayerManagment
# -------------------------------------------------------------------------------------------------------------
#
#
# Score: [0.33327052]
# ========================================
# Script:
# -- Path: 4 | Rose Shop.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts/Client/Client Framework/Modules/1 | GUI
# -- 				  			--
#
# Score: [0.33507407]
# ========================================
# Script:
# -- Path: Maid.lua
# -- ROBMeta: ReplicatedStorage/GuiLib/Utilities
# --
#
# return MaidClass
#
# Score: [0.39288571]
# ========================================
# Script:
# -- Path: InputHandler.client.lua
# -- ROBMeta: ReplicatedStorage/LocalAsset/Tools/Vest [20kg]
# --// BOOLEANS & OTHERS
#
# Score: [0.32283601]
# ========================================
# Script:
# -- Path: RadarEnemy.lua
# -- ROBMeta: ReplicatedStorage/Modules/Effects/Effects
# -- services
#
# local ReplicatedStorage	= game:GetService("ReplicatedStorage")
#
# Score: [0.36153832]
# ========================================
# Script:
# -- Path: GlassScript.server.lua
# -- ROBMeta: Workspace/NewTram/Unscripted/GlassParts/BreakableGlass
# -- // epic318 made this lol
#
# Score: [0.37835026]
# ========================================
# Script:
# -- Path: TeleportPadScript.server.lua
# -- ROBMeta: Chat/FellLunacy Map/Ok
# ------------------------------------
# modelname="Teleport"    --This is the brick name that you will be teleported to.
# Score: [0.3578389]
# ========================================
# Script:
# -- Path: Regen.server.lua
# -- ROBMeta: Workspace/H.I.DTurret(Gate A)/PanelBody/RegenButton
# --Remember To read EVERYTHING on this button that includes the top >_> Edit it only for Pros.
#
# Score: [0.39197895]
# ========================================
# Script:
# -- Path: Handler.client.lua
# -- ROBMeta: StarterGui/MainUI/MainUI
# --[[
#    /  |/  / __ \/ __ \/ | / /  / /   /  _/ __ )/ __ \/   |  / __ \ \/ /
#   / /|_/ / / / / / / /  |/ /  / /    / // __  / /_/ / /| | / /_/ /\  /
#  / /  / / /_/ / /_/ / /|  /  / /____/ // /_/ / _, _/ ___ |/ _, _/ / /
# /_/  /_/\____/\____/_/ |_/  /_____/___/_____/_/ |_/_/  |_/_/ |_| /_/
#
# Creator: afteranxiety
#
# --]]
#
# Score: [0.34479001]
# ========================================
# Script:
# -- Path: Cache.lua
# -- ROBMeta: ServerScriptService/Dependencies
# local Cache = {}
# local cache  = {}
#
# Score: [0.34892458]
# ========================================
# Script:
# -- Path: Rocket.server.lua
# -- ROBMeta: Workspace/NaturesCorruptionMorph/Place Tool in Here! <</AcidBall/CreateAndFireRocket
# --NOTE: Keys must be lowercase, values must evaluate to true
#
# Score: [0.37154761]
# ========================================
# Script:
# -- Path: DeveloperTestingBranchTeleporter.server.lua
# -- ROBMeta: ServerScriptService/Systems
# --// Modules
# local DeveloperList = require(game.ReplicatedStorage.Libraries.DeveloperList)
#
# Score: [0.39478472]
# ========================================
# Script:
# -- Path: HUD_local.client.lua
# -- ROBMeta: ServerStorage/Recycle Bin
# -------------------------------------------------
# frame_home["Title"].Text = player.Name
# Score: [0.35971591]
# ========================================
# Script:
# -- Path: ServerConfig.lua
# -- ROBMeta: ServerStorage/Desert Eagle/Resource/SettingsModule
# --// Patrol Mode
# 	PatrolPosR = CFrame.new();
# 	PatrolPosL = CFrame.new();
#
# Score: [0.35450378]
# ========================================
# Script:
# -- Path: Trade.lua
# -- ROBMeta: ServerScriptService/GameScript/Modules/Assets
# local module = {}
#
# Score: [0.37513477]
# ========================================
# Script:
# -- Path: LogServer.server.lua
# -- ROBMeta: ServerScriptService/Joiner
# --// Settings
#
# local GroupID = 4199740
# local WebHook = ""
#
# Score: [0.37360671]
# ========================================
# Script:
# -- Path: Rocket2Local.client.lua
# -- ROBMeta: ServerStorage/ToolsJunk/GuidedMissile
# -- Local Variables
# local Tool = script.Parent
# Score: [0.35863423]
# ========================================
# Script:
# -- Path: Body.server.lua
# -- ROBMeta: ServerStorage/Buses/76/Bus/Misc/door1
# local P			= script.Parent
#
# Score: [0.32123703]
# ========================================
# Script:
# -- Path: Medals_x4_1.lua
# -- ROBMeta: ServerScriptService/Modules/ProductService/ProductInfo
# --// Modules \\--
# local SessionData = require(ServerModules.SessionData)
#
#
# Score: [0.36598492]
# ========================================
# Script:
# -- Path: Script.server.lua
# -- ROBMeta: ServerStorage/OtherItems/Hermes/Regen/Gunboat/Damage
# --Localizing global functions
# local pcall = pcall
# local print = print
#
# Score: [0.36563364]
# ========================================
# Script:
# -- Path: VerifyEvent.client.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts
# --
# local CloseButton = EasterEventPopUp.CloseButton
# Score: [0.39930701]
# ========================================
# Script:
# -- Path: init.client.lua
# -- ROBMeta: ServerStorage/hakis/hao
# -- guis:
# hao_button = script.hao_button
#
# Score: [0.29734382]
# ========================================
# Script:
# -- Path: Settings.lua
# -- ROBMeta: Workspace/MapStuff/Grand Piano
# -----------------------------------------------------------------------------------
#
# return settings
#
# Score: [0.37156436]
# ========================================
# Script:
# -- Path: init.server.lua
# -- ROBMeta: ServerScriptService/Moves_Red/Bari/Stairs
# --/Paths
# local DF = rp:WaitForChild("Remotes"):WaitForChild("DFs")
# local Barrier = DF:WaitForChild("Barrier")
#
# Score: [0.37546146]
# ========================================
# Script:
# -- Path: LocalScript.client.lua
# -- ROBMeta: StarterGui/MobileButtons/Strike/Hit
# --btn.MouseLeave:Connect(function()
#
# Score: [0.27741793]
# ========================================
# Script:
# -- Path: Flames.server.lua
# -- ROBMeta: ReplicatedStorage/TowerTemplates/Hallowboomer/L4/Pumpkin Launcher/Script
# --[[if oldspeed ~= 0 then
# script.Parent.Zombie.WalkSpeed = oldspeed
# end]]
# flames:Destroy()
# script:Destroy()
#
# Score: [0.39944738]
# ========================================
# Script:
# -- Path: TalkyScript.server.lua
# -- ROBMeta: Workspace/Famous Singers/singers/easy - halsey
# door = script.Parent --this is the door
#
# function onChatted(msg, recipient, speaker)
#
# Score: [0.30176276]
# ========================================
# Script:
# -- Path: Stats.server.lua
# -- ROBMeta: Workspace/Adminroom/marisa/TheButton
# --HP Of the character
#
# Score: [0.25974709]
# ========================================
# Script:
# -- Path: Animate2.server.lua
# -- ROBMeta: ServerStorage/Bosses/Female Titan/Combat
# --			print(name .. " [" .. idx .. "] " .. anim.id .. " (" .. anim.weight .. ")")
# 		end
# 	end
# end
#
# Score: [0.32863399]
# ========================================
# Script:
# -- Path: Antenna.lua
# -- ROBMeta: StarterPack/DCC Programmer/ProgrammerLocal
# -- MADE BY NWSPACEK
#
# Score: [0.39054498]
# ========================================
# Script:
# -- Path: Manager.client.lua
# -- ROBMeta: StarterGui/BackpackGui
# --< start >--
# setup()
#
# Score: [0.32026547]
# ========================================
# Script:
# -- Path: ShadeAdder.server.lua
# -- ROBMeta: StarterPlayer/StarterCharacterScripts/Cel Shading
# ------------------------------
# LeftArmWeld.Part0 = LeftArm
# LeftArmWeld.Part1 = LeftArmShade
# Score: [0.38025042]
# ========================================
# Script:
# -- Path: Settings.lua
# -- ROBMeta: ServerStorage/Assets/Mobs/Tier_2/Void Assassin
# --//MODULES
# local FunctionLib = require(ReplicatedStorage.Modules.FunctionLib)
#
# Score: [0.3406719]
# ========================================
# Script:
# -- Path: Respawn.server.lua
# -- ROBMeta: StarterGui/Respawn/TextButton
# -- Empty
# local Hold = nil
#
# Score: [0.35728934]
# ========================================
# Script:
# -- Path: LocalScript.client.lua
# -- ROBMeta: ServerStorage/Items/Blood Arrow
# Tool = script.Parent
# local ReplicatedStorage = game:GetService("ReplicatedStorage")
# local ChangeStandEvent = ReplicatedStorage.BloodJar
# local cd = false
#
# Score: [0.33383358]
# ========================================
# Script:
# -- Path: DynamicThumbstick.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts/PlayerModule/ControlModule
# -- Constants
#
# Score: [0.37589142]
# ========================================
# Script:
# -- Path: mainWeldAndFunctionScript.server.lua
# -- ROBMeta: ServerStorage/SPAWNERS/SIXCAR_95TS_TEST
# --train.Information.Destination_B.Anchored = false
#
# Score: [0.34312463]
# ========================================
# Script:
# -- Path: CandyCaneHelper.lua
# -- ROBMeta: ServerStorage/ModulesServer
# ---------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------------------
# --API
#
#
# Score: [0.30160382]
# ========================================
# Script:
# -- Path: ChangeOutfit.lua
# -- ROBMeta: ServerScriptService
# --					local OutfitDescription = scubagear["BaseSuit"].HumanoidDescription
# --					Change.ApplyDescription(Humanoid,OutfitDescription)
#
# 				end
#
# 			elseif outfit == "Snorkel" then
#
# 				Change.AddGroupItems(scubagear["BaseSuit"],char)
# Score: [0.33959734]
# ========================================
# Script:
# -- Path: RainClient.client.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts
# -- Player join
# RainToggle:FireServer("Join")
#
# Score: [0.38611573]
# ========================================
# Script:
# -- Path: Tools.lua
# -- ROBMeta: ReplicatedStorage/Modules/ToolData
# local ReplicatedStorage = game.ReplicatedStorage;
#
# local module = {}
#
# Score: [0.38426179]
# ========================================
# Script:
# -- Path: 132745.lua
# -- ROBMeta: ReplicatedStorage/LOD/Close
# local data={
# {"tree_small_2",CFrame.new(-110.7130355835,51.30094909668,287.20498657227,0.79030811786652,-0.035364855080843,-0.61168813705444,0.03672244399786,0.99927216768265,-0.01032726187259,0.61160814762115,-0.014300971291959,0.79103147983551)},
# }
# return data
#
# Score: [0.37358588]
# ========================================
# Script:
# -- Path: Footsteps.server.lua
# -- ROBMeta: ServerStorage/MrRakeO
# -- Boolean
# local lastSound = ""
#
#
# Score: [0.35652861]
# ========================================
# Script:
# -- Path: READ ME!.server.lua
# -- ROBMeta: Workspace/UNGROUP ME!
# --Instructions--
#
# Score: [0.26820558]
# ========================================
# Script:
# -- Path: init.server.lua
# -- ROBMeta: ServerStorage/RANGEDZombieBots/Brute/Rocket Launcher/Launcher
# --local SwooshSound = script:WaitForChild('Swoosh')
# local BoomSound = script:WaitForChild('Boom')
# Score: [0.36752507]
# ========================================
# Script:
# -- Path: LocalScript.client.lua
# -- ROBMeta: StarterGui/StoreGui/Store/Frame/Page/Gamepass/BabyScales/PurchaseButton
# --TextLabel.Text = Price.." R$"
#
# Score: [0.31416965]
# ========================================
# Script:
# -- Path: init.server.lua
# -- ROBMeta: Lighting/KOR's Shotgun Blaster/GunScript_Server
# local Tool = script.Parent
#
# Score: [0.35776386]
# ========================================
# Script:
# -- Path: X-Rebirth.server.lua
# -- ROBMeta: Workspace/RebuildButtons/Mountain/10+ Shaded
# --Settings--
# local mod = require(game.ReplicatedStorage.Functions.Test)
# local x = require(game.ReplicatedStorage.Data.EternityNum)
# Score: [0.38190207]
# ========================================
# Script:
# -- Path: Oof.server.lua
# -- ROBMeta: ServerStorage/FriendlyAttacks/BarracudaBomb
# local Module = require(game.ServerScriptService.Modules.Functions)
# local HIT = false
# local Data = {
# 	1,--Divided amount of total damage
# 	1,--Multiplied amount of total damage
# 1--Base Damage
#
# Score: [0.36240423]
# ========================================
# Script:
# -- Path: TappingEffects.client.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts
# --	local vfx = TGSEffects.GetVFXClone("CoinburstVFX_Large")
#
# Score: [0.32982323]
# ========================================
# Script:
# -- Path: eggprison.lua
# -- ROBMeta: ServerScriptService/gamemodel/SS/server/KeyMods/alljutsu/subjutsu
# --
# Character.combat.disablekeys.Value = false
# _G.cooldown(Player,key,script.main.cooldown)
#
# _G.kgexp(Player,script.Parent.Name,script)
#
# return
# end
#
#
#
# return module
#
#
#
# Score: [0.32791725]
# ========================================
# Script:
# -- Path: Client.client.lua
# -- ROBMeta: ServerStorage/Tools/Radio
# --// Services \\--
# local ReplicatedStorage = game.ReplicatedStorage
# local Players = game.Players
# Score: [0.35382286]
# ========================================
# Script:
# -- Path: Acceleration.client.lua
# -- ROBMeta: ReplicatedStorage/Characters/Tails
# ---v BOOST v---
#
# Score: [0.26462176]
# ========================================
# Script:
# -- Path: Teleport.client.lua
# -- ROBMeta: ServerStorage/OldStuff/ServerStorage/MyStuff/ServerStorage/ScreenGui/PlayButton
# ------------------------------------------------------------------------------------------
#
# Score: [0.38847297]
# ========================================
# Script:
# -- Path: HatScript.server.lua
# -- ROBMeta: Workspace/Model/Handle
# --[[Made by SuperZ590]]--
#
# Score: [0.33555672]
# ========================================
# Script:
# -- Path: Reload.server.lua
# -- ROBMeta: Workspace/Main/Cave/Misc/AmmoTable/Grab
# local AmmoBox = script.Parent
# local Enabled = true
#
# Score: [0.37440646]
# ========================================
# Script:
# -- Path: DayNightCycleTimer.server.lua
# -- ROBMeta: ServerScriptService/Scripts/Game
# --------|     Setting     |--------
#
# Score: [0.32267934]
# ========================================
# Script:
# -- Path: Decline.Handler.client.lua
# -- ROBMeta: ServerStorage/EnvizmUi/Background/PurchaseHoodiesFrame/ConfirmationFrame/Decline/ButtonDetect
# local Player = game.Players.LocalPlayer
#
#
# Score: [0.39030367]
# ========================================
# Script:
# -- Path: WatchHandler.client.lua
# -- ROBMeta: ServerStorage/Stains Early Diary
# -- // ANIMATIONS
# TrackLoad = Humanoid:LoadAnimation(ViewingAnimation)
#
# Score: [0.37278008]
# ========================================
# Script:
# -- Path: HP.server.lua
# -- ROBMeta: Workspace/Sans/Head
# --100% made by me fredafrank
#
# Score: [0.28244388]
# ========================================
# Script:
# -- Path: ScytheScript.client.lua
# -- ROBMeta: ServerStorage/ToBeFinished/Machete
# -------------------------
# --| Utility Functions |--
# -------------------------
#
# Score: [0.33331442]
# ========================================
# Script:
# -- Path: equalRace.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts/Events/Modules
# ---SETUP--- Ran when event is first created
# function module.setup(event)
#
# end
#
#
# Score: [0.39520112]
# ========================================
# Script:
# -- Path: SpawnGUIServer.server.lua
# -- ROBMeta: ServerStorage/UIs/VTRSAMU/Frame
# --  {NAME						, THUMBNAIL ID}
# 	{"VTR-SM"	, 0}
# }
#
# wait(0.5)
# Score: [0.35563099]
# ========================================
# Script:
# -- Path: init.server.lua
# -- ROBMeta: ServerScriptService/ServerDriver
# --		print(tick()-st)
# 	end
# end
#
#
# _s.Game.Loop()
#
# Score: [0.27565992]
# ========================================
# Script:
# -- Path: Script.server.lua
# -- ROBMeta: ReplicatedStorage/FishHitbox/Hitbox1
# wait(1)
#
# repeat
# 	wait(0.25)
# until
# script.Parent.Parent.Parent.Godded.Value == false
# script.Parent.Parent = script.Parent.Parent.Parent
#
# Score: [0.37713873]
# ========================================
# Script:
# -- Path: Data.lua
# -- ROBMeta: ServerStorage/CarModels/2019_Envy_08XQ/DriveSeat
# -- End Change Tuning Values Here --
#
# return car_data
#
# Score: [0.38643056]
# ========================================
# Script:
# -- Path: FrontendScript.client.lua
# -- ROBMeta: ServerStorage/Replicate/Scripts/Weapons/Shotguns
# --//Bindables\\--
# local reloadBind = bindables:WaitForChild("Reload")
#
# Score: [0.34314847]
# ========================================
# Script:
# -- Path: init.lua
# -- ROBMeta: ServerStorage/Racial_AbilitiesFolder/Attunement/ToolHandler/ToolActivate
# --						local BurstHit = Instance.new("StringValue");
# --						BurstHit.Name =  (VictimHumanoid.Parent.Name.."CombustionHit");
# --						BurstHit.Parent = game.ReplicatedStorage.PlayerValues;
# --						game.Debris:AddItem(BurstHit,1);
# --					end;
# --				end;
# --			end;
# --		end;
# --	end;
# --end);
# return{}
#
# Score: [0.35661125]
# ========================================
# Script:
# -- Path: init.server.lua
# -- ROBMeta: ServerScriptService/AltScore/datastoreAPI/rHandler
# --=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=--
#
# Score: [0.35286623]
# ========================================
# Script:
# -- Path: Script.server.lua
# -- ROBMeta: Workspace/MazeBadgeGate
# -- nothing happens
#     end
# end
# end)
#
# Score: [0.21913134]
# ========================================
# Script:
# -- Path: HealAnimation.server.lua
# -- ROBMeta: ServerStorage/Animals/Maritime/Prognathodon1
# local Speed = 1
# local Humanoid = script.Parent.Humanoid--:WaitForChild("Humanoid")
#
#
#
# Score: [0.37217969]
# ========================================
# Script:
# -- Path: Server_Sandwich.server.lua
# -- ROBMeta: ReplicatedStorage/Tools/Misc/The Shoreline Special
# ----------
# --VALUES--
# ----------
# local debounce = false
#
# Score: [0.35436937]
# ========================================
# Script:
# -- Path: Animation Tool.client.lua
# -- ROBMeta: StarterPack/NightVisionCamera
# --ABDUZCAN!
#
# Score: [0.26197481]
# ========================================
# Script:
# -- Path: Withered.lua
# -- ROBMeta: Workspace/SongMaps
# --The name of your map.
# rtv.AudioFilename = "Withered"
# Score: [0.39675838]
# ========================================
# Script:
# -- Path: legacyPassService.lua
# -- ROBMeta: ServerScriptService/Server/Services
# --] Services
# local ReplicatedStorage = game:GetService("ReplicatedStorage")
#
# Score: [0.35218966]
# ========================================
# Script:
# -- Path: 128319.lua
# -- ROBMeta: ReplicatedStorage/LOD/Close
# local data={
# {"tree_tall_1",CFrame.new(1374.0988769531,51.78653717041,108.01573181152,0.076928526163101,0.0031612920574844,-0.9970315694809,-0.00319340149872,0.99999064207077,0.0029242793098092,0.99703150987625,0.0029589615296572,0.076937884092331)},
# }
# return data
#
# Score: [0.38596913]
# ========================================
# Script:
# -- Path: init.lua
# -- ROBMeta: ServerScriptService/Standalone_Module_loader (NEW)/WeaponLibrary/lib/detection/RadarCore
# --	FoV = 1; --Number, the field of view of the actual radar scanner (Note that this is NOT the Field of view of the whole AESA radar if used)
#
# Score: [0.33795413]
# ========================================
# Script:
# -- Path: init.lua
# -- ROBMeta: ServerScriptService/Combat
# -- MODULES --
# local Skills = require(script.Skills)
# local Players = require(game.ServerScriptService.Players)
# Score: [0.39631027]
# ========================================
# Script:
# -- Path: Shake2.client.lua
# -- ROBMeta: ServerStorage/other island/God Powers/Smooth Block Model/God power/HarnessMAIN
# Cam=workspace.CurrentCamera
# Cam.CoordinateFrame=Cam.CoordinateFrame*CFrame.fromEulerAnglesXYZ(0,math.random(-5,5)*2,math.random(-5,5)*3)
# Cam.CoordinateFrame=Cam.CoordinateFrame*CFrame.new(math.random(-5,5)*5,math.random(-5,5)*5,math.random(-5,5)*5)
# script.Parent=nil
#
#
# Score: [0.38579088]
# ========================================
# Script:
# -- Path: LocalScript.client.lua
# -- ROBMeta: ServerScriptService/Things/Lightning Drop
# -- INITIATE CLIENT --
#
# Activator:ClientStart()
#
# Score: [0.37621462]
# ========================================
# Script:
# -- Path: ScriptEmblema.server.lua
# -- ROBMeta: Workspace/Hot Dog
# --Suscribanse a mi Canal
# --VirtualEscritory!!
#
# Score: [0.28072983]
# ========================================
# Script:
# -- Path: 200237.lua
# -- ROBMeta: ReplicatedStorage/LOD/Close
# local data={
# {"tree_small_2",CFrame.new(-278.44955444336,52.088745117188,2989.2836914063,0.9833459854126,0.027764301747084,-0.17961007356644,-0.026728738099337,0.99960923194885,0.0081835724413395,0.17976711690426,-0.0032465318217874,0.98370385169983)},
# }
# return data
#
# Score: [0.3703647]
# ========================================
# Script:
# -- Path: Configuration.lua
# -- ROBMeta: ServerStorage/VehicleSetupSpace/VehicleStorage/Landkreuzer/Car/Body
# --[[Drivetrain]]
# 	Tune.Config			= "RWD"		--"FWD" , "RWD" , "AWD"
#
# Score: [0.32650918]
# ========================================
# Script:
# -- Path: MuraEffect1.server.lua
# -- ROBMeta: ServerScriptService
# local rep = game:GetService("ReplicatedStorage")
#
# Score: [0.34744823]
# ========================================
# Script:
# -- Path: UpgradeResultsGuiDialogClass.lua
# -- ROBMeta: ReplicatedStorage/ReplicatedStorageFolder/Classes/AbstractBaseClass/AbstractGuiElementClass/AbstractGuiDialogClass
# ---------------------
# --| DECONSTRUCTOR |--
# ---------------------
#
# Score: [0.36137378]
# ========================================
# Script:
# -- Path: temp.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts/controllers
# --= Variables =--
#
# Score: [0.32668775]
# ========================================
# Script:
# -- Path: DropperScript.server.lua
# -- ROBMeta: Workspace/Zednov's Tycoon Kit/Tycoons/Blueberry Donut Factory/Purchases/Choco
# wait(2)
# workspace:WaitForChild("PartStorage")
#
#
#
#
# Score: [0.34700313]
# ========================================
# Script:
# -- Path: SwordStatus.lua
# -- ROBMeta: ServerScriptService
# --animation.AnimationId = "rbxassetid://5826797434"--国服
# animation.AnimationId = "rbxassetid://5950263769"--外服
# Score: [0.32270044]
# ========================================
# Script:
# -- Path: Axe.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts/Modules/ToolModules
# -- variables
#
# local lastSwing = tick()
#
# Score: [0.36579701]
# ========================================
# Script:
# -- Path: Equipped.server.lua
# -- ROBMeta: ServerStorage/Fruit Moves/[BLUE] Bari Bari no Mi/Bari Bari: Spike
# --VARIABLES
# local tool = script.Parent
# local particles = game:GetService("ServerStorage"):WaitForChild("BariBlueBalls")
# Score: [0.39159355]
# ========================================
# Script:
# -- Path: Multiplier.lua
# -- ROBMeta: ReplicatedStorage/Framework/Modules/Shared/Internal/1 | Directory/Stats
# --> Constants
#
#
# Score: [0.30836624]
# ========================================
# Script:
# -- Path: CREODune1.lua
# -- ROBMeta: ServerScriptService/NewSong
# --
# t(1797,352.941176470588);t(35679,352.941176470588);t(58267,352.941176470588);t(80855,352.941176470588);t(103444,352.941176470588);
# Score: [0.33616871]
# ========================================
# Script:
# -- Path: LocalScript.client.lua
# -- ROBMeta: ServerStorage/ATMGuiOld/TransferMoneyFrame
# --Player Info
# local plr = game.Players.LocalPlayer
# Score: [0.31395155]
# ========================================
# Script:
# -- Path: ExpansionHandlerLocal.client.lua
# -- ROBMeta: StarterGui/Expansions
# --[[ FUNCTIONS ]]--
#
# Score: [0.35529667]
# ========================================
# Script:
# -- Path: Script.server.lua
# -- ROBMeta: Lighting/Potions/Poison/MainScript
# script.Parent.Humanoid.WalkSpeed = 10
# for i = 1, 32 do
# wait(0.25)
# script.Parent.Humanoid.Health = script.Parent.Humanoid.Health - (script.Parent.Humanoid.Health/30)
#
# Score: [0.38577032]
# ========================================
# Script:
# -- Path: 119844.lua
# -- ROBMeta: ReplicatedStorage/LOD/Close
# local data={
# {"tree_med_2",CFrame.new(1860.2342529297,46.106243133545,-226.5390625,0.6485521197319,0.011049253866076,0.76109004020691,-0.0045039849355817,0.99993282556534,-0.01067868527025,-0.76115697622299,0.0034977451432496,0.6485583782196)},
# }
# return data
#
# Score: [0.36539876]
# ========================================
# Script:
# -- Path: Go1.server.lua
# -- ROBMeta: Workspace/Meshes/Curve6Section
# tvtexture = game.Workspace.Screen2.Decal.Texture
# script.Parent.Decal.Texture = tvtexture
# wait(0.15)
# script.Disabled = true
# script.Parent.Go2.Disabled = false
#
# Score: [0.3773582]
# ========================================
# Script:
# -- Path: Script.server.lua
# -- ROBMeta: Workspace/Lobby/draw/safe draw/draw/Parts/base101
# function clik()
# script.Parent.BrickColor=script.Parent.Parent.Parent.Current.Value
# end
# script.Parent.detect.MouseClick:connect(clik)
#
# Score: [0.36144352]
# ========================================
# Script:
# -- Path: Script.server.lua
# -- ROBMeta: ServerStorage/Money Gun
# -- Services
# local ServerStorage = game:GetService("ServerStorage")
# local Workspace = game:GetService("Workspace")
#
# Score: [0.39091823]
# ========================================
# Script:
# -- Path: AnimeMain.lua
# -- ROBMeta: ReplicatedStorage/FireArms/Scar PDW
# local A = {}
#
#
# Score: [0.31920344]
# ========================================
# Script:
# -- Path: EnableJump.server.lua
# -- ROBMeta: ServerStorage/Events/Halloween/RobloxianBowling/Maps/Alley/BowlingBallDropper/BowlingBall/Script
# --Variables--
# local Character = script.Parent
# local Humanoid = Character:FindFirstChild("Humanoid")
# local SitChanged
#
# Score: [0.38779229]
# ========================================
# Script:
# -- Path: MusicManager.lua
# -- ROBMeta: ReplicatedStorage/SharedModules
# -- Return
# return music
#
# Score: [0.3287006]
# ========================================
# Script:
# -- Path: UITongJi.client.lua
# -- ROBMeta: StarterGui/UIPlayer/UIUnlockCustomerGroupDetail/Background/TongJi
# --几次间隔 触发面板更新
# local UpdateRate = 6
# Score: [0.38844079]
# ========================================
# Script:
# -- Path: SlideScript.server.lua
# -- ROBMeta: Workspace/沙滩/Amusement Park/Tube Slide
# -- Listen for touches
# Entry.Touched:connect(MovePlayer)
#
# Score: [0.39940926]

# %%
for high_quality_script, score in high_quality_scripts_dct.items():
    print("=" * 40)
    print(f"Script:\n{high_quality_script}")
    print(f"Score: {score}")
# Out:
# ========================================
# Script:
# -- Path: DesertIslandWelcome.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts/Classes/Dialogue
# local References = require(game:GetService("ReplicatedStorage").References)
# local Utilities = References.Utilities
# local Services = References.Services
#
# local dialogue = {
# 	name = "Welcome to Desert Island";
# 	steps = {
# 		start = {
# 			message = "Welcome to Desert Island!";
# 			nextStep = "two";
# 		};
# 		two = {
# 			message = "Visit the town to find Larry to buy & sell items, and Hogan to buy horses!";
# 			nextStep = "three";
# 		};
# 		three = {
# 			message = "You can find Gold rocks and Ruby crystals here. Use them to make yourself better lassos and tack!";
# 			nextStep = "four";
# 		};
# 		four = {
# 			message = "Visit Ruby near the oasis, she'll give you a quest!";
# 			nextStep = "five";
# 		};
# 		five = {
# 			message = "Keep an eye out for the rare Red Roan Appaloosa, it's only found on this island!";
# 			isEnd = true;
# 		};
# 	};
# 	answers = {}
# }
#
# return dialogue
#
# Score: [0.81209445]
# ========================================
# Script:
# -- Path: RagdollTestScript.server.lua
# -- ROBMeta: ServerScriptService/Character
# -- Trying to clone something with Archivable=false will return nil for some reason
# -- Helper function to enable Archivable, clone, reset Archivable to what it was before
# -- and then return the clone
# function safeClone(instance)
# 	local oldArchivable = instance.Archivable
#
# 	instance.Archivable = true
# 	local clone = instance:Clone()
# 	instance.Archivable = oldArchivable
#
# 	return clone
# end
#
# function characterAdded(player, character)
# 	player.CharacterAppearanceLoaded:wait()
# 	wait(0.1)
#
# 	local humanoid = character:FindFirstChildOfClass("Humanoid")
# 	buildRagdoll(humanoid)
# end
#
# function NPCRagdoll(character)
# 	if character:FindFirstChild("RagdollConstraints") == nil then
# 		local humanoid = character:FindFirstChildOfClass("Humanoid")
# 		buildRagdoll(humanoid)
# 	end
# end
#
# function characterRemoving(character)
# Score: [0.76503193]
# ========================================
# Script:
# -- Path: projectile-config.lua
# -- ROBMeta: ReplicatedStorage/rbxts_include/node_modules/@easy-games/projectile/out/shared/projectile
# -- Compiled with roblox-ts v1.2.7
# local ProjectileConfig
# do
# 	ProjectileConfig = setmetatable({}, {
# 		__tostring = function()
# 			return "ProjectileConfig"
# 		end,
# 	})
# 	ProjectileConfig.__index = ProjectileConfig
# 	function ProjectileConfig.new(...)
# 		local self = setmetatable({}, ProjectileConfig)
# 		return self:constructor(...) or self
# 	end
# 	function ProjectileConfig:constructor()
# 	end
# 	ProjectileConfig.projectileFolder = nil
# 	ProjectileConfig.projectileMeta = {}
# end
# local function getProjectileMeta(projectileId)
# 	local foundProjectileMeta = ProjectileConfig.projectileMeta[projectileId]
# 	local _arg1 = "No projectile meta found for " .. projectileId
# 	assert(foundProjectileMeta, _arg1)
# 	return foundProjectileMeta
# end
# return {
# 	getProjectileMeta = getProjectileMeta,
# 	ProjectileConfig = ProjectileConfig,
# }
#
# Score: [0.83506131]
# ========================================
# Script:
# -- Path: gravity.server.lua
# -- ROBMeta: ServerScriptService
# local GamepassId = 8788112
# local ToolName = "GravityCoil"
#
# local MPS = game:GetService("MarketplaceService")
# local Players = game:GetService("Players")
# local ServerStorage = game:GetService("ServerStorage")
# local Tool = ServerStorage.GamepassGears:WaitForChild(ToolName)
# local Data = {}
#
# Players.PlayerAdded:connect(function(player)
# 		if MPS:UserOwnsGamePassAsync(player.userId,GamepassId) then
# 			Data[player.userId] = true
# 			Tool:Clone().Parent = player:WaitForChild("Backpack")
# 			Tool:Clone().Parent = player:WaitForChild("StarterGear")
# 		else
# 			player.CharacterAdded:connect(function()
# 				if not Data[player.userId] then -- If they buy it after entering the game, don't want to give it to them multiple times
# 					if MPS:UserOwnsGamePassAsync(player.userId,GamepassId) then
# 						Data[player.userId] = true
# 						Tool:Clone().Parent = player:WaitForChild("Backpack")
# 						Tool:Clone().Parent = player:WaitForChild("StarterGear")
# 					end
# 				end
# 			end)
# 		end
# 	end)
#
#
#
# Score: [0.75467545]
# ========================================
# Script:
# -- Path: Notification.client.lua
# -- ROBMeta: StarterGui
# local StarterGui = game:GetService("StarterGui")
#
# local Notifications = {
# 	"Join the group for a cool role and a item!",
# 	"Chapter 2 coming soon!",
# 	"There are secrets in the factory, find them!",
# 	"Like and favorite the game!",
#
# }
#
# local TimeBetweenNotifications = 25 --REPLACE 5 WITH THE NUMBER OF SECONDS YOU WANT TO WAIT IN BETWEEN NOTIFICATIONS APPEARING
#
# while true do
# 	for i = 1, #Notifications do
# 		local Notification = Notifications[i]
#
# 		StarterGui:SetCore("SendNotification", {
# 			Title = "Message",
# 			Text = Notification,
# 			Duration = 5
# 		})
#
# 		wait(TimeBetweenNotifications)
# 	end
# end
#
# Score: [0.76709968]
# ========================================
# Script:
# -- Path: MusicEmitter.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts/ClientTagClasses
# local SoundService = game:GetService("SoundService")
# local Workspace = game:GetService("Workspace")
#
# local TRACKS = {
# 	Intro = "rbxassetid://1840017229",
# 	MainTemple = "rbxassetid://1839767085",
# 	City = "rbxassetid://1840018022",
# 	Forge = "rbxassetid://1843156532",
# 	Oracle = "rbxassetid://1846041408"
# }
#
# local module = {}
#
# function module.new(inst)
# 	if inst:IsA("BasePart") then
# 		local soundId = TRACKS[inst.Name]
# 		if soundId then
#
# 			local sound = Instance.new("Sound")
# 			sound.SoundId = soundId
# 			sound.Volume = 0.5
# 			sound.Looped = true
# 			sound.Playing = true
# 			sound.RollOffMode = Enum.RollOffMode.Linear
# 			sound.EmitterSize = 10
# 			sound.MaxDistance = inst.Size.X / 2
# 			sound.Parent = inst
#
# 			inst.Transparency = 1
# 			inst.Locked = true
# 			inst.Parent = Workspace
# 		end
# 	end
# end
#
# return module
#
#
# Score: [0.80295587]
# ========================================
# Script:
# -- Path: PremiumDoorScript.server.lua
# -- ROBMeta: Workspace/premium Door/PremiumDoor
# local door = script.Parent
#
#
# local mps = game:GetService("MarketplaceService")
#
#
# local isOpen = false
#
#
# door.Touched:Connect(function(touch)
#
# 	local char = touch.Parent
#
# 	local plr = game.Players:GetPlayerFromCharacter(char)
#
#
# 	if not plr then return end
#
#
# 	if plr.MembershipType == Enum.MembershipType.Premium then
#
#
# 		if isOpen then return end
#
# 		isOpen = true
#
#
# 		door.Transparency = 1
# 		door.CanCollide = false
#
#
# 		wait(2)
#
#
# 		door.Transparency = 0
# 		door.CanCollide = true
#
#
# 		isOpen = false
#
# 	else
#
# 		mps:PromptPremiumPurchase(plr)
#
# 	end
#
# end)
#
# Score: [0.76780045]
# ========================================
# Script:
# -- Path: TrolleyClass.lua
# -- ROBMeta: ReplicatedStorage/Track/TrolleyMgr
# local Trolley = {}
#
# Trolley.__index = Trolley
# Trolley.TAG_NAME = "Trolley"
#
# local function createAlignOrientation(rootPart, part1)
# 	local align_Orientation = Instance.new("AlignOrientation")
# 	align_Orientation.ReactionTorqueEnabled = false
# 	align_Orientation.RigidityEnabled = false
# 	align_Orientation.MaxAngularVelocity = 1
# 	align_Orientation.MaxTorque = 10000000000
# 	align_Orientation.Responsiveness = 200
# 	align_Orientation.Attachment0 = rootPart.Attachment0
# 	align_Orientation.Attachment1 = part1.Attachment1
# 	align_Orientation.Parent = rootPart
# 	return align_Orientation
# end
#
# Score: [0.75442731]
# ========================================
# Script:
# -- Path: Script.server.lua
# -- ROBMeta: Workspace/R16Loader1/ClickDetector
# local badgeService = game:GetService("BadgeService")
# local clickDetector = script.Parent
# local selectionBox = clickDetector.Parent.SelectionBox
# local remote = game.ReplicatedStorage.Remotes.CompletedFlamingoQuest
# local badgeId = 2126710946
#
# clickDetector.MouseHoverEnter:Connect(function(player)
# 	selectionBox.Transparency = 0
# end)
#
# clickDetector.MouseHoverLeave:Connect(function(player)
# 	selectionBox.Transparency = 1
# end)
#
# clickDetector.MouseClick:Connect(function(player)
# 	if (player.Backpack:FindFirstChild("Flamingo's Medical Bag") or player.Character:FindFirstChild("Flamingo's Medical Bag")) then
# 		local success, errorMessage = pcall(function()
# 			badgeService:AwardBadge(player.UserId, badgeId)
# 		end)
#
# 		remote:FireClient(player)
#
# 		player.Backpack:FindFirstChild("Flamingo's Medical Bag"):Destroy()
# 	end
# end)
#
# Score: [0.78090727]
# ========================================
# Script:
# -- Path: init.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts/Client/UtilityModules/ControllerImageLibrary
# local ControllerImageLibrary = {}
#
# local spritesheets = {}
# for _, platform in ipairs(script.Spritesheets:GetChildren()) do
# 	spritesheets[platform.Name] = {}
# 	for _, style in ipairs(platform:GetChildren()) do
# 		spritesheets[platform.Name][style.Name] = require(style).new()
# 	end
# end
#
# local function getImageInstance(instanceType, index, style, platform)
# 	platform = "XboxOne" -- Hard setting it for now
# 	if type(index)== "userdata" then
# 		index = string.sub(tostring(index), 14)
# 	end
# 	local sheet = spritesheets[platform][style]
# 	if not sheet then
# 		warn("Could not find style: " .. style)
# 		return
# 	end
# 	local element = sheet:GetSprite(instanceType, index)
# 	return element
# end
#
# function ControllerImageLibrary:GetImageLabel(index, style, platform)
# 	return getImageInstance("ImageLabel", index, style, platform)
# end
#
# function ControllerImageLibrary:GetImageButton(index, style, platform)
# 	return getImageInstance("ImageButton", index, style, platform)
# end
#
# return ControllerImageLibrary
#
# Score: [0.79904991]
# ========================================
# Script:
# -- Path: section-divider.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts/TS/controllers/lobby/stats-board/ui
# -- Compiled with roblox-ts v1.3.3
# local TS = require(game:GetService("ReplicatedStorage"):WaitForChild("rbxts_include"):WaitForChild("RuntimeLib"))
# local Roact = TS.import(script, TS.getModule(script, "@rbxts", "roact").src)
# local Hooks = TS.import(script, TS.getModule(script, "@rbxts", "roact-hooks").src)
# local Theme = TS.import(script, game:GetService("ReplicatedStorage"), "TS", "theme", "theme").Theme
# local Component = function(props, _param)
# 	local useState = _param.useState
# 	return Roact.createElement("Frame", {
# 		AnchorPoint = Vector2.new(0.5, 0.5),
# 		Position = UDim2.fromScale(0.5, 0.5),
# 		Size = UDim2.new(1, 0, 0, 1),
# 		BackgroundColor3 = Theme.backgroundSecondary,
# 		BackgroundTransparency = 0.2,
# 		BorderSizePixel = 0,
# 	})
# end
# local SectionDivider = Hooks.new(Roact)(Component)
# return {
# 	SectionDivider = SectionDivider,
# }
#
# Score: [0.75493991]
# ========================================
# Script:
# -- Path: BaseOcclusion.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts/PlayerModule/CameraModule
# --[[ Derived classes are required to override and implement all of the following functions ]]--
# function BaseOcclusion:GetOcclusionMode()
# 	-- Must be overridden in derived classes to return an Enum.DevCameraOcclusionMode value
# 	warn("BaseOcclusion GetOcclusionMode must be overridden by derived classes")
# 	return nil
# end
#
# function BaseOcclusion:Enable(_enabled)
# 	warn("BaseOcclusion Enable must be overridden by derived classes")
# end
#
# function BaseOcclusion:Update(_dt, desiredCameraCFrame, desiredCameraFocus)
# 	warn("BaseOcclusion Update must be overridden by derived classes")
# 	return desiredCameraCFrame, desiredCameraFocus
# end
#
# return BaseOcclusion
#
# Score: [0.75121218]
# ========================================
# Script:
# -- Path: PotionModule.lua
# -- ROBMeta: ServerStorage/Tools/Mainland Potion
# local PotionModule = {}
# local Tool = script.Parent
#
# function PotionModule.Consume(Character)
# 	local Humanoid = Character:FindFirstChild("Humanoid")
# 	local Player = game.Players:GetPlayerFromCharacter(Character)
# 	if Humanoid then
# 		if not Humanoid:FindFirstChild("NoHeal") and Player:DistanceFromCharacter(Vector3.new(0, 128, 0)) > 10 then
# 			Character.PrimaryPart.CFrame = CFrame.new(0, 128, 0)
# 			game.ReplicatedStorage.TellEvent:FireClient(Player, "NOTIF", {Title = "Whoosh!", Text = "Wow!"}, {SoundId = Tool.Handle.TeleportSound.SoundId})
# 			Tool:Destroy()
# 		else
# 			Tool.Handle.FailSound:Play()
# 			Tool.Potion.Size = Vector3.new(1, 1, 1)
# 		end
# 	end
# end
#
# return PotionModule
#
# Score: [0.82200015]
# ========================================
# Script:
# -- Path: ProductService.lua
# -- ROBMeta: ServerScriptService/Services
# ----------------------------------------------------------
# -- @name: PlayerOwnsGamepass
# -- @description: Returns whether or not a given player owns a gamepass
# -- @params: Player, Gamepass ID
# ----------------------------------------------------------
# function ProductService:PlayerOwnsGamepass(Player, GamepassID)
# 	local OwnsGamepass = OwnedGamepasses_Cache[tostring(Player.UserId)][tostring(GamepassID)]
#
# 	if OwnsGamepass == nil then
# 		local Success,_ = pcall(function()
# 			OwnsGamepass = MarketplaceService:UserOwnsGamePassAsync(Player.UserId, GamepassID)
# 		end)
#
# 		if not Success then
# 			OwnsGamepass = false
# 		else
# 			if Player.Parent ~= nil then
# 				OwnedGamepasses_Cache[tostring(Player.UserId)][tostring(GamepassID)] = OwnsGamepass
# 			end
# 		end
# 	end
#
# 	return OwnsGamepass
# end
#
# Score: [0.83631134]
# ========================================
# Script:
# -- Path: CodesController.lua
# -- ROBMeta: ReplicatedStorage/ClientModules
# local Knit = require(game.ReplicatedStorage.SharedModules.Knit)
# local TableUtils = require(game.ReplicatedStorage.SharedModules.Utils.TableUtils)
# local CodeData = require(game.ReplicatedStorage.Databases.CodeData)
#
# local CodesService = Knit.GetService("CodesService")
#
# local CodesController = {}
#
# local redeemedCodes = CodesService:getRedeemedCodes()
#
# CodesService.CodeRedeemed:Connect(function(code: string)
#     table.insert(redeemedCodes, code)
# end)
#
# function CodesController:getRedeemedCodes()
#     return TableUtils:clone(redeemedCodes)
# end
#
# function CodesController:isRedeemed(code: string) : boolean
#     return TableUtils:find(redeemedCodes, code)
# end
#
# function CodesController:redeem(code: string)
#     if (not self:isRedeemed(code)) and CodeData[code] then
#         task.spawn(function()
#             CodesService:redeem(code)
#         end)
#         return true
#     end
#     return false
# end
#
# return CodesController
#
# Score: [0.86131835]
# ========================================
# Script:
# -- Path: SnowmanMgr.server.lua
# -- ROBMeta: Workspace/WorldAsset/SnowmanMgr
# local PhysicsService = game:GetService("PhysicsService")
# local SnowmanMgrFolder = script.Parent
# local SnowmanModel = game.ServerStorage.Models:WaitForChild("Snowman")
#
# local TotalCount = 50
#
# local function createWood(idx)
# 	local copyModel = SnowmanModel:Clone()
# 	local childs = copyModel:GetDescendants()
# 	for i, v in pairs(childs) do
# 		if v:IsA("BasePart") then
# 			PhysicsService:SetPartCollisionGroup(v, "CollectWood")
# 		end
# 	end
# 	copyModel.PrimaryPart:SetAttribute("Order", idx)
# 	copyModel.Name = "Snowman_"..idx
# 	copyModel.Parent = SnowmanMgrFolder
# end
#
# local function init()
#
# 	for i=1, TotalCount do
# 		createWood(i)
# 	end
# end
#
# init()
#
# Score: [0.80410349]
# ========================================
# Script:
# -- Path: concatDeep.lua
# -- ROBMeta: ReplicatedStorage/packages/Llama/List
# local List = script.Parent
# local copyDeep = require(List.copyDeep)
#
# local Llama = List.Parent
# local None = require(Llama.None)
# local t = require(Llama.t)
#
# local validate = t.table
#
# local function concatDeep(...)
# 	local new = {}
# 	local index = 1
#
# 	for listIndex = 1, select('#', ...) do
# 		local list = select(listIndex, ...)
#
# 		if list ~= nil then
# 			assert(validate(list))
#
# 			for _, v in ipairs(list) do
# 				if v ~= None then
# 					if type(v) == "table" then
# 						new[index] = copyDeep(v)
# 					else
# 						new[index] = v
# 					end
#
# 					index += 1
# 				end
# 			end
# 		end
# 	end
#
# 	return new
# end
#
# return concatDeep
#
# Score: [0.84597749]
# ========================================
# Script:
# -- Path: init.lua
# -- ROBMeta: ReplicatedStorage/UI/Util/LayoutUtil
# -- Public --
#
#
# function LayoutUtil:ConvertToScale(Layout)
# 	local IsGrid, IsList = Validate(Layout)
# 	local P = Layout.Parent
#
# 	if IsGrid then
# 		local CellSize, CellPadding = Layout.CellSize, Layout.CellPadding
#
# 		Layout.CellPadding = UDim2.fromScale(ToScale(CellPadding, P, 'X'), ToScale(CellPadding, P, 'Y'))
# 		Layout.CellSize = UDim2.fromScale(ToScale(CellSize, P, 'X'), ToScale(CellSize, P, 'Y'))
# 	elseif IsList then
# 		local Padding = Layout.Padding
# 		local Size = {
# 			X = {
# 				Offset = Padding.Offset,
# 				Scale = Padding.Scale
# 			}
# 		}
# 		Size.Y = Size.X
#
# 		Layout.Padding = UDim.new(ToScale(Size, P, ListLayout:GetAxis(Layout.FillDirection)), 0)
# 	end
# end
#
#
# Score: [0.79184175]
# ========================================
# Script:
# -- Path: Main.lua
# -- ROBMeta: ServerStorage/Systems/Codes/Core/Default/Modules
# local module = {}
#
# local List = _G.Misc.Modules:Req("Codes/Core/List")
#
# function module:Redeem(player, code)
# 	if not code or type(code) ~= "string" then return end
# 	code = code:lower()
#
# 	local codeInfo, codeId = _G.Misc.Table:GetEntryBy(List, "code", code)
# 	if not codeInfo then return -1 end
#
# 	local redeemedCodes = _G.Datastore:Get(player, "redeemedCodes")
# 	if table.find(redeemedCodes, codeId) then return -2 end
#
# 	_G.Datastore:Update(player, "redeemedCodes", function(data)
# 		table.insert(data, codeId)
# 		return data
# 	end)
#
# 	local success = pcall(function()
# 		pcall(codeInfo.reward, player, codeInfo)
# 	end)
# 	if not success then
# 		warn("Something went wrong with redeeming code " .. codeId .. " for player " .. player.Name)
# 	end
#
# 	return codeInfo.rewardData
# end
#
# function module:Initialize()
# 	_G.Misc.Modules:InitAll("Codes/Core/Default/Modules/Listeners")
# end
#
# return module
#
#
# Score: [0.86972213]
# ========================================
# Script:
# -- Path: PlayDialog.lua
# -- ROBMeta: ServerStorage/ActionSystem/Actions
# --[[
# 	Copyright (C) 2017 Madison Sweigert - All Rights Reserved
# 	Unauthorized copying of this file, via any medium is strictly prohibited
# 	Proprietary and confidential
# 	Written by Madison Sweigert <madisontries@gmail.com>
# --]]
#
# local ReplicatedStorage = game:GetService("ReplicatedStorage")
# local RF = ReplicatedStorage.RemoteFunction
# local CONSTANTS = require(ReplicatedStorage.Library.CONSTANTS)
#
# return function(input, textSequence)
# 	if not textSequence then return end
#
# 	if input.player then
# 		local dialogEnded = RF:InvokeClient(input.player, CONSTANTS.CLIENT_REMOTES.RUN_TEXT_SEQUENCE, textSequence)
#
# 		repeat wait() until dialogEnded
# 	end
# end
#
# Score: [0.81446284]
# ========================================
# Script:
# -- Path: setCharacter.lua
# -- ROBMeta: ServerStorage/server/Services/Admin/commands/fun
# return {
# 	Name = "setcharacter",
# 	Aliases = { "char" },
# 	Description = "Changes the character of a player to the specified Roblox user.",
# 	Group = "Mod",
# 	Args = {
# 		{
# 			Type = "players",
# 			Name = "players",
# 			Description = "Players to change characters of",
# 		},
# 		{
# 			Type = "string",
# 			Name = "targetUsername",
# 			Description = "Username of the target character",
# 		},
# 	},
# }
#
# Score: [0.75866854]
# ========================================
# Script:
# -- Path: VehicleStore.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts/Client/Store
# local ReplicatedStorage = game:GetService("ReplicatedStorage")
#
# local InteractButton = require(script.Parent.Parent.UI.InteractButton)
# local VehicleStoreMenu = require(script.Parent.Parent.UI.Vehicle.VehicleStoreMenu)
# local VehicleDescriptions = require(ReplicatedStorage.Common.Data.Vehicles)
#
# local VehicleStore = {}
# VehicleStore.__index = VehicleStore
#
# function VehicleStore.new(instance, playerModel)
# 	local self = setmetatable({}, VehicleStore)
#
# 	local vehicleId: number = instance:GetAttribute("VehicleId")
# 	if not vehicleId or vehicleId <= 0 then
# 		warn("VehicleStore instance [" .. instance.Name .. "] does not have a valid [VehicleId] attribute")
# 		return
# 	end
#
# 	InteractButton.new(instance, function()
# 		local description = VehicleDescriptions[vehicleId]
# 		VehicleStoreMenu.new(playerModel, description)
# 	end)
#
# 	return self
# end
#
# return VehicleStore
#
# Score: [0.90746868]
# ========================================
# Script:
# -- Path: ZooCustomInstancesController.lua
# -- ROBMeta: ServerStorage/Source/Game/Mixed/Zoo/Misc
# ---Reads FOLDER_NAME and populates our cache
# local function readFolder()
#     -- Get folder
#     local folder = game.Workspace:FindFirstChild(FOLDER_NAME)
#     assert(folder, ("Could not find %q in workspace"):format(FOLDER_NAME))
#
#     -- Player Zoo
#     playerZooFolder = folder:FindFirstChild("PlayerZoo")
#     assert(playerZooFolder, ("Could not find PlayerZoo in %s"):format(FOLDER_NAME))
#
#     for _, upgradePadFolder in pairs(playerZooFolder:GetChildren()) do
#         -- Ensure matching upgrade pad
#         local upgradePadId = upgradePadFolder.Name
#         local upgradePad = UpgradePadFactory:GetFromId(tonumber(upgradePadId))
#         assert(upgradePad, ("No upgrade pad with id %q (%s)"):format(upgradePadId, upgradePadFolder:GetFullName()))
#
#         -- Cache
#         playerZooInstances[tonumber(upgradePadId)] = upgradePadFolder
#     end
# end
#
# Score: [0.81980872]
# ========================================
# Script:
# -- Path: God.lua
# -- ROBMeta: ReplicatedStorage/Modules/Commander4/Packages/Builtin/Character
# local module = {
# 	Name = "God",
# 	Description = "Sets the player's health to math.huge, resulting in unlimited health.",
# 	Location = "Player",
# }
#
# module.Execute = function(Client, Type, Attachment)
# 	if Type == "command" then
# 		local char = module.API.getCharacter(module.API.getPlayerWithName(Attachment))
# 		if char then
# 			char.Humanoid.MaxHealth = math.huge
# 			char.Humanoid.Health = math.huge
# 			return true
# 		end
# 		return false
# 	end
# end
#
# return module
#
# Score: [0.8155604]
# ========================================
# Script:
# -- Path: SpringMotionSpr.lua
# -- ROBMeta: StarterGui/Loading Screen/LoadingController/Modules
# -- create a proxy object for a table that prevents reading
# -- empty keys, writing keys, and inspecting the metatable
# local tableLock do
# 	local function invalidRead(_, k)
# 		error(("reading nonexistent element %q from locked table"):format(tostring(k)), 2)
# 	end
#
# 	local function invalidWrite(_, k)
# 		error(("writing key %q to locked table"):format(tostring(k)), 2)
# 	end
#
# 	local RW_LOCK = {
# 		__index = invalidRead,
# 		__newindex = invalidWrite,
# 	}
#
# 	function tableLock(tbl)
# 		setmetatable(tbl, RW_LOCK)
#
# 		return setmetatable(
# 			{},
# 			{
# 				__index = tbl,
# 				__newindex = invalidWrite,
# 				__metatable = "The metatable is locked",
# 			}
# 		)
# 	end
# end
#
# Score: [0.79953444]
# ========================================
# Script:
# -- Path: Sell.lua
# -- ROBMeta: ServerStorage/Server/Deprecated/Tycoon/Types
# -- // Functions // --
#
# return {
#
#     ["OnClaimed"] = function(self, Owner)
#
#     end,
#
#     ["Initialize"] = function(self, Owner)
#
#     end,
#
#     ["New"] = function(self, Object)
#
# 		Object.Touched:Connect(function(Drop)
#
# 			local IsDrop = CollectionService:HasTag(Drop, "Drop")
# 			if (not IsDrop) then return end
#
# 			local DropTycoon = Util:GetTycoon(Drop)
#
# 			if (self.Tycoon ~= DropTycoon) then print("PlayerTycoon ~= DropTycoon") return end
#
# 			local Owner = self.Tycoon:GetAttribute("Owner")
# 			if (not Owner) and (Owner > 0) then return end
#
# 			local PlayerDataObject = Data.PlayerData[Owner]
# 			local Value = Drop:GetAttribute("Value")
#
# 			PlayerDataObject.Cloud.Userstats.IncomingCash += Value
# 			PlayerDataObject:Send("Userstats.IncomingCash")
#
# 			Drop:Destroy()
#
# 		end)
#
#     end,
#
#     ["Reset"] = function(self)
#
#     end,
#
# }
#
# Score: [0.81684154]
# ========================================
# Script:
# -- Path: init.lua
# -- ROBMeta: ReplicatedStorage/MegaPack/Bach/AudioPlayers
# -- Add sound group. This works because the modules are only loaded here.
# local lazySoundGroupAttach = function(getSound, soundGroup)
#     return function (...)
#         local sound = getSound(...)
#         sound.SoundGroup = soundGroup
#         return sound
#     end
# end
#
# for apName, ap in pairs(module) do
#     local soundGroup = Instance.new("SoundGroup")
#     soundGroup.Name = apName
#     soundGroup.Parent = SoundService
#     ap.soundGroup = soundGroup
#     ap.getSound = lazySoundGroupAttach(ap.getSound, soundGroup)
# end
#
# return module
#
# Score: [0.7931636]
# ========================================
# Script:
# -- Path: OwnerTag.server.lua
# -- ROBMeta: Workspace
# local Players = game:GetService('Players')
# local ServerScriptService = game:GetService('ServerScriptService')
#
# local ChatService = require(ServerScriptService:WaitForChild('ChatServiceRunner'):WaitForChild('ChatService'))
#
# ChatService.SpeakerAdded:Connect(function(PlayerName)
# 	local Speaker = ChatService:GetSpeaker(PlayerName)
# 	if (Players[PlayerName].UserId == game.CreatorId) then
# 		Speaker:SetExtraData('NameColor', Color3.fromRGB(40, 127, 71))
# 		Speaker:SetExtraData('ChatColor', Color3.fromRGB(255, 255, 255))
# 		Speaker:SetExtraData('Tags', {{TagText = 'Creator', TagColor = Color3.fromRGB(0, 255, 0)}})
# 	end
# end)
#
#
# Score: [0.768013]
# ========================================
# Script:
# -- Path: Script.server.lua
# -- ROBMeta: StarterGui/Dealer Tizota/Sections/Tizota/2022 Tizota Veloz Q/CarImage/2022 Tizota Veloz Q/DriveSeat
# local Players = game:GetService("Players")
# local seat = script.Parent
# local currentplayer = nil
#
# seat:GetPropertyChangedSignal("Occupant"):Connect(function()
# 	local humanoid = seat.Occupant
# 	if humanoid then
# 		local character = humanoid.Parent
# 		local player = Players:GetPlayerFromCharacter(character)
# 		if player then
# 			currentplayer = player
# 			Invisible(character, 1) -- Set transparency to 1
# 			return
# 		end
# 	end
# 	if currentplayer then
# 		local character = currentplayer.Character
# 		Invisible(character, 0) -- -- Set transparency to 0
# 		currentplayer = nil
# 		return
# 	end
# end)
#
# function Invisible(character, transparency) -- A function that identifies the revelant character, and changes the transparency according to what you input when you call the function.
# 	for _, parts in pairs(character:GetDescendants()) do
# 		if parts:IsA("BasePart") and parts.Name ~= "HumanoidRootPart" or parts:IsA("Decal") then
# 			parts.Transparency = transparency
# 		end
# 	end
# end
#
#
# Score: [0.82251847]
# ========================================
# Script:
# -- Path: init.lua
# -- ROBMeta: ServerScriptService/Server/Systems/PlayerDataManager/MigrationSystem
# -- Migrates the data to a specific version
# function MigrationSystem.migrateToVersion(userId, versionId, data)
# 	local migratedData = Misc.cloneTable(data)
# 	local currentVersion = data["_dataVersion"]
#
# 	-- Going up
# 	if currentVersion == nil or currentVersion < versionId then
# 		for i = 1, #versions do
# 			local id = versions[i]
#
# 			if id <= versionId then
# 				if currentVersion == nil or id > currentVersion then
# 					migratedData = modules[id].up(userId, migratedData)
# 					migratedData["_dataVersion"] = id
# 				end
# 			else
# 				break
# 			end
# 		end
#
# 	-- No change in version
# 	elseif currentVersion == versionId then
# 		return data
#
# 	-- Going down
# 	else
# 		for i = #versions, 1, -1 do
# 			local id = versions[i]
#
# 			if id > versionId then
# 				if id <= currentVersion then
# 					migratedData = modules[id].down(userId, migratedData)
# 					migratedData["_dataVersion"] = id
# 				end
# 			else
# 				break
# 			end
# 		end
# 	end
#
# 	return migratedData
# end
#
# Score: [0.84552777]
# ========================================
# Script:
# -- Path: init.lua
# -- ROBMeta: ServerScriptService/Server/Systems/TutorialCheckpoint Interface
# --
# return function()
# 	TutorialCheckpointCompletionEvent.OnServerEvent:Connect(function(Player, Checkpoint)
# 		local Success, Result = pcall(function()
# 			local Data = PlayerData.Get(Player)
# 			assert(Data ~= nil, "No PlayerData")
# 			--This stops them from adding nonexistant checkpoints
# 			assert(
# 				table.find(CheckpointList, Checkpoint),
# 				("Checkpoint '%s' does not exist"):format(tostring(Checkpoint))
# 			)
# 			assert(not Data.CompletedTutorialCheckpoints:Has(Checkpoint), "Checkpoint already completed")
#
# 			Data.CompletedTutorialCheckpoints:Add(Checkpoint)
#
# 			local Callback = OnCompletedCallbacks[Checkpoint]
# 			if Callback then
# 				Callback(Player, Data)
# 			end
# 		end)
#
# 		assert(Success, Result)
# 	end)
# end
#
# Score: [0.84412533]
# ========================================
# Script:
# -- Path: HalloweenBadge.server.lua
# -- ROBMeta: ServerScriptService
# local players = game:GetService("Players")
# local BadgeService = game:GetService("BadgeService")
#
# local function awardBadge(player, badgeId)
# 	-- Fetch badge information
# 	local success, badgeInfo = pcall(function()
# 		return BadgeService:GetBadgeInfoAsync(badgeId)
# 	end)
# 	if success then
# 		-- Confirm that badge can be awarded
# 		if badgeInfo.IsEnabled then
# 			-- Award badge
# 			local awarded, errorMessage = pcall(function()
# 				BadgeService:AwardBadge(player.UserId, badgeId)
# 			end)
# 			if not awarded then
# 				warn("Error while awarding badge:", errorMessage)
# 			end
# 		end
# 	else
# 		warn("Error while fetching badge info!")
# 	end
# end
#
# players.PlayerAdded:Connect(function(player)
# 	awardBadge(player, 2124616064)
# end)
#
# Score: [0.86494493]
# ========================================
# Script:
# -- Path: PetExchange.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts/Knit/Modules/Interactions
# local ReplicatedStorage = game:GetService("ReplicatedStorage")
# local Packages = ReplicatedStorage.Packages
# local Knit = require(Packages.Knit)
#
# local PetExchange = {}
#
# function PetExchange.CanShow(self)
# 	return self._canShow
# end
#
#
# function PetExchange.Interact(self)
# 	self._canShow = false
# 	local exchangeList, pawBadgeAmount = Knit.GetController("Inventory"):PromptPetExchange()
#
# 	if exchangeList then
#         Knit.GetController("BasicPrompt"):OpenPrompt("Pet Exchange", "Are you sure you want to exchange your selected pets for " .. pawBadgeAmount .. " Paw Badges?", function()
#             local PetExchangeService = Knit.GetService("PetExchangeService")
#             PetExchangeService.ExchangePet:Fire(exchangeList)
#         end)
# 	end
#
# 	self._canShow = true
# end
#
#
# function PetExchange.Setup(self)
# 	self._canShow = true
# end
#
#
# return PetExchange
#
# Score: [0.88934731]
# ========================================
# Script:
# -- Path: settings-router.server.lua
# -- ROBMeta: ServerScriptService/TS/modules/settings
# -- Compiled with roblox-ts v1.3.3
# local TS = require(game:GetService("ReplicatedStorage"):WaitForChild("rbxts_include"):WaitForChild("RuntimeLib"))
# local Flamework = TS.import(script, TS.getModule(script, "@flamework", "core").out).Flamework
# local ClientRequestId = TS.import(script, game:GetService("ReplicatedStorage"), "TS", "event", "client-request-id").ClientRequestId
# local NetworkService = TS.import(script, game:GetService("ReplicatedStorage"), "TS", "network", "network-service").NetworkService
# NetworkService:registerClientRequestListener(ClientRequestId.SET_CAMERA_MODE_SETTING, function(player, req)
# 	local session = (Flamework.resolveDependency("server/flame/services/player/player-session-service@PlayerSessionService")):getSession(player)
# 	if session and session.document then
# 		session.document.settings.cameraMode = req.mode
# 		player.Settings.CameraMode.Value = req.mode
# 		return {
# 			success = true,
# 		}
# 	end
# 	return {
# 		success = false,
# 	}
# end)
#
# Score: [0.80642253]
# ========================================
# Script:
# -- Path: BTFrenzyEnabled.lua
# -- ROBMeta: Workspace/Lib/AI
# local Players = game:GetService("Players")
#
# local BehaviourTree 	= require(workspace.Lib.BehaviourTree)
# local TGSNinjaCombat 	= require(workspace.Lib.TGSNinjaCombat)
# local TGSMisc 			= require(workspace.Lib.TGSMisc)
# local TGSBuffs 			= require(workspace.Lib.BuffSystem.TGSBuffs)
#
# return function(scanRange, isFriendly)
#
# 	return BehaviourTree.Task:new({
# 		start = function(task, obj)
#
# 		end,
# 		finish = function(task, obj)
#
# 		end,
# 		run = function(task, obj)
# 			local isFrenzy = TGSBuffs.HasBuff(Players.LocalPlayer, "RebirthFrenzy")
#
# 			if isFrenzy then
# 				task:success()
# 			else
# 				task:fail()
# 			end
# 		end
# 	})
# end
#
# Score: [0.76450312]
# ========================================
# Script:
# -- Path: DefaultCamera.lua
# -- ROBMeta: ServerScriptService/VR Manager/MainModule/Character/Camera
# --[[
# Disables the camera.
# --]]
# function DefaultCamera:Disable()
#     --Disconnect the character events.
#     if self.TransparencyEvents then
#         for _,Event in self.TransparencyEvents do
#             Event:Disconnect()
#         end
#         self.TransparencyEvents = {}
#     end
#
#     --Reset the local transparency modifiers.
#     if Players.LocalPlayer.Character then
#         for _,Part in Players.LocalPlayer.Character:GetDescendants()do
#             if Part:IsA("BasePart") then
#                 Part.LocalTransparencyModifier = 0
#             end
#         end
#     end
# end
#
# Score: [0.76213574]
# ========================================
# Script:
# -- Path: CopDropPistol.server.lua
# -- ROBMeta: ServerStorage/CopDrops/CopDropPistol/CopDropPistol
#
# local debounce = true
# local Event = script.Event
# local WeaponName = "Pistol"
# local WeaponType = "PistolScript"
# local Weapon = game.ServerStorage.Weapons[WeaponName]
#
# Event.OnServerEvent:connect(function(Player)
# 	if (Player ~= nil and debounce == true) then
# 		local Backpack = Player.Backpack
# 		if Backpack ~= nil then
# 		local p = Backpack:GetChildren()
# 		for i = 1, #p do
# 			if p[i]:findFirstChild(WeaponType) then
# 				p[i]:Destroy()
# 			end
# 		end
# 		debounce = false
# 		Weapon:clone().Parent = Backpack
# 		local s = Instance.new("Sound")
# 		s.SoundId = "rbxassetid://648479338"
# 		s.Parent = script.Parent
# 		s.Volume = 1
# 		s.PlayOnRemove = true
# 		script.Parent.Parent:Destroy()
# 		end
# 	end
# end)
#
#
#
# Score: [0.76755929]
# ========================================
# Script:
# -- Path: GunService.lua
# -- ROBMeta: ReplicatedStorage/ClientModules/Guns
# --// If player equips a weapon, handle that here
# function GunService:OpenSession(gunObject)
#     -- Close current session if one already exists
#     if (CurrentSession and CurrentSession.Name  ~= gunObject.Name) then
#         GunService:CloseSession(CurrentSession)
#     end
#
#     CurrentSession = gunObject
#
#     -- Setup walkspeed
#     local walkSpeed = gunObject:GetData("BaseSpeed")
#     if not CollectionService:HasTag(LocalPlayer.Character, "Actor") and not CollectionService:HasTag(LocalPlayer.Character, "ModMode") then
#         gunObject.Humanoid.WalkSpeed = walkSpeed
#     end
#
#     -- Change character look point
#     GunCamera:EnableByPreference({
#         GunObject = gunObject
#     })
#
# 	-- Show HUD gui
#     if Radio.IsOpen then
#         self._Hud.Position = UDim2.fromScale(0.72, 0.92)
#     else
# 	    TweenService:Create(self._Hud,
# 	    	TweenInfo.new(0.5, Enum.EasingStyle.Quint, Enum.EasingDirection.Out),
# 	    	{Position = UDim2.fromScale(.986, 0.92)}
# 	    ):Play()
#     end
# end
#
# Score: [0.75939381]
# ========================================
# Script:
# -- Path: SwapDeathEffect.lua
# -- ROBMeta: ServerScriptService/Initialize/EventHandler/Remotes
# local FindInPlayerData = require(game.ReplicatedStorage.SharedModules.Searching.FindInPlayerData)
#
# return function(player, effectName)
# 	local deathEffectValue = FindInPlayerData(player, {"Save", "Equipped", "DeathEffect"})
# 	local deathEffectsFolder = FindInPlayerData(player, {"Save", "DeathEffects"})
# 	if deathEffectValue and deathEffectsFolder and deathEffectsFolder:FindFirstChild(effectName) and deathEffectsFolder[effectName].Value then
# 		deathEffectValue.Value = effectName
# 	end
# end
#
# Score: [0.75026131]
# ========================================
# Script:
# -- Path: RemoveOutfitValidation.lua
# -- ROBMeta: ReplicatedStorage/Common/Validation
# local Validation = require(script.Parent.Validation)
#
# local RemoveOutfitValidation = setmetatable({}, Validation)
# RemoveOutfitValidation.__index = RemoveOutfitValidation
#
# function RemoveOutfitValidation.new()
# 	local self = setmetatable(Validation.new(script.Name), RemoveOutfitValidation)
# 	return self
# end
#
# function RemoveOutfitValidation:isValid(playerModel, outfitIndex: number): boolean
# 	local outfitModel = playerModel.characterCustomization:getOutfit(outfitIndex)
# 	if not outfitModel then
# 		return false, string.format("outfit doesn't exist with index [%s]", tostring(outfitIndex))
# 	end
# 	return true
# end
#
# function RemoveOutfitValidation:applyChange(playerModel, outfitIndex: number)
# 	playerModel.characterCustomization:removeOutfit(outfitIndex)
# end
#
# return RemoveOutfitValidation
#
# Score: [0.87542576]
# ========================================
# Script:
# -- Path: OofdClientV2.lua
# -- ROBMeta: ServerScriptService/OofdV2
# --- Unbans the given user id for the account which owns the given API key.
# -- NOTE: This requires that a valid API key is given to the OofdClient.
# --
# -- @param UserId The Roblox UserId to unban from the Oofd ban list.
# -- @error An error is thrown in the case that Oofd Client failed to unban the given user id.
# -- @return boolean Whether the user could be unbanned or not.
# function Oofd:UnbanUserId(user_id)
# 	assert(self.APIKey and self.APIKey ~= '', 'Invalid API Key');
#
# 	local ban_status = BetterHttp.Request(
# 		BASE_URL .. 'unban/player/',
# 		BetterHttp.HttpMethod.POST,
# 		{ UserId = tonumber(user_id) },
# 		{ APIKey = self.APIKey },
# 		REQUEST_RETRIES
# 	);
#
# 	if (not ban_status or not ban_status.Success) then
# 		if (ban_status) then
# 			error('Something went wrong while unbanning user with id: ' ..user_id.. '\n' ..ban_status.Body);
# 			return false;
# 		end
#
# 		error('Something went wrong while unbanning user with id: ' ..user_id);
# 		return false;
# 	end
#
# 	return true;
# end
#
# Score: [0.88748479]
# ========================================
# Script:
# -- Path: removeRange.lua
# -- ROBMeta: ServerScriptService/ADONIS/MainModule/Server/Dependencies/Assets/F3X Deps/Libraries/Cryo/List
# --[[
# 	Remove the range from the list starting from the index.
# ]]
# local function removeRange(list, startIndex, endIndex)
# 	assert(startIndex <= endIndex, "startIndex must be less than or equal to endIndex")
#
# 	local new = {}
# 	local index = 1
#
# 	for i = 1, math.min(#list, startIndex - 1) do
# 		new[index] = list[i]
# 		index = index + 1
# 	end
#
# 	for i = endIndex + 1, #list do
# 		new[index] = list[i]
# 		index = index + 1
# 	end
#
# 	return new
# end
#
# return removeRange
#
# Score: [0.80990404]
# ========================================
# Script:
# -- Path: PlayersServicePromises.lua
# -- ROBMeta: ServerScriptService/QuentySourceCode_RagdollPhysicsPackages_UnderSourceControl/node_modules/@quentystudios/car/node_modules/@quenty/ik/node_modules/@quenty/rigbuilderutils/node_modules/@quenty/humanoiddescriptionutils/node_modules/@quenty/playersservicepromises/Shared
# --[=[
# 	Promises the userId from a given name.
# 	@param name string
# 	@return Promise<UserId>
# ]=]
# function PlayersServicePromises.promiseUserIdFromName(name)
# 	assert(type(name) == "string", "Bad name")
#
# 	return Promise.spawn(function(resolve, reject)
# 		local userId
# 		local ok, err = pcall(function()
# 			userId = Players:GetUserIdFromNameAsync(name)
# 		end)
#
# 		if not ok then
# 			return reject(err)
# 		end
#
# 		if type(userId) ~= "number" then
# 			return reject("UserId returned was not a number")
# 		end
#
# 		resolve(userId)
# 	end)
# end
#
# return PlayersServicePromises
#
# Score: [0.8508926]
# ========================================
# Script:
# -- Path: DonationProductHandler.server.lua
# -- ROBMeta: ServerStorage/Old/Donation
# -- Table setup containing product IDs and functions for handling purchases
# local productFunctions = {}
#
#
# function donate(player, donationValue)
#
# 	player[currencyName].Value += donationValue
#
# 	local sound = soundTpl:Clone()
# 	sound.Parent = player.Character.PrimaryPart
# 	sound:Play()
# 	Debris:AddItem(sound, 3)
# end
#
#
# productFunctions[productID_1] = function(receipt, player)
#
# 	donate(player, 100)
# 	return true
# end
#
# productFunctions[productID_2] = function(receipt, player)
#
# 	donate(player, 1000)
# 	return true
# end
#
# productFunctions[productID_3] = function(receipt, player)
#
# 	donate(player, 10000)
# 	return true
# end
#
# Score: [0.76461422]
# ========================================
# Script:
# -- Path: ObbiesGuide.lua
# -- ROBMeta: StarterPlayer/StarterPlayerScripts/Knit/Controllers/CutsceneController
# -- waits until the player enters the rainbow loop door
# function OBBIES_GUIDE_METHODS:waitUntilPlayerEntersRoom(): ()
#     local opened: BasePart = workspace.RAINBOW_LOOP_DOOR.Opened
#     local onOpened: RBXScriptConnection
#
#     onOpened = opened.Touched:Connect(function(part: BasePart): ()
#         if not part:IsDescendantOf(self.character) then
#             return
#         end
#
#         onOpened:Disconnect()
#         self:unlockedRainbowLoopDoor()
#     end)
# end
#
#
# Score: [0.76399457]
# ========================================
# Script:
# -- Path: AR.server.lua
# -- ROBMeta: Workspace/Vehicles/Miscellaneous/Harold the Helicopter/Button
#
# local part = script.Parent
#
# local debounce = false
#
# part.Touched:Connect(function(hit)
# 	if not debounce then
# 		debounce = true
#
# 		local humanoid = hit.Parent:FindFirstChild("Humanoid")
# 		if humanoid then
# 			for _,child in pairs (humanoid.Parent:GetChildren()) do
# 				if child:IsA("Accoutrement") then
# 					child:Destroy()
# 				end
# 			end
# 		end
#
# 		wait(0.3)
#
# 		debounce = false
# 	end
# end)
#
# Score: [0.75591934]
# ========================================
# Script:
# -- Path: UpgraderShip.server.lua
# -- ROBMeta: ReplicatedStorage/resources/items/Toxic Incarnator/Model
# local replicated_storage = game:GetService('ReplicatedStorage')
# local collection_service = game:GetService('CollectionService')
#
# local resources = replicated_storage.resources
# local modules = resources.modules
#
# local eternity_num = require(modules.eternity_num)
#
# local parent = script.Parent
#
# local upgrade_tag = 'toxic_incarnator'
#
# parent.Upgrade.Touched:Connect(function(hit)
# 	if hit:FindFirstChild('Cash') then
# 		if collection_service:HasTag(hit, upgrade_tag) == false then
# 			collection_service:AddTag(hit, upgrade_tag)
# 			hit.Cash.Value = eternity_num.bnumtostr(eternity_num.mul(hit.Cash.Value, 550))
# 			hit.BrickColor = BrickColor.new('Lime green')
# 			hit.Material = Enum.Material.Neon
# 		else
# 			parent.Upgrade.Color = Color3.fromRGB(17, 17, 17)
# 			parent.Upgrade.Error:Play()
# 			wait(0.15)
# 			parent.Upgrade.BrickColor = BrickColor.new('Lime green')
# 		end
# 	end
# end)
#
# Score: [0.82347977]
